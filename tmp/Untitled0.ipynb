# %%
from google.colab import drive
import os

drive.mount('/content/drive')
os.chdir("drive/Othercomputers/pc/VF2pp-in-CUDA/tmp/")
# Out:
# Mounted at /content/drive

# %%
# !pip install nvcc4jupyter
# !pip install pycuda
# !nvidia-smi
# !nvcc --version
# %load_ext nvcc4jupyter
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.7/1.7 MB 25.6 MB/s eta 0:00:00
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 88.6/88.6 kB 10.0 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 78.6/78.6 kB 13.1 MB/s eta 0:00:00
# ...
#   Created wheel for pycuda: filename=pycuda-2024.1-cp310-cp310-linux_x86_64.whl size=661206 sha256=5658295ca5b6bb475c82b3c2ac15faab5b75597025778c7f9699ee8ee2f3c8e1
#   Stored in directory: /root/.cache/pip/wheels/12/34/d2/9a349255a4eca3a486d82c79d21e138ce2ccd90f414d9d72b8
# Successfully built pycuda
# ...
# Sun Jul  7 16:00:33 2024
# +---------------------------------------------------------------------------------------+
# | NVIDIA-SMI 535.104.05             Driver Version: 535.104.05   CUDA Version: 12.2     |
# |-----------------------------------------+----------------------+----------------------+
# ...

# %%
! gcc -c graph_list.c -o graph_list.o
! rm m

# %%
# !nvcc -arch=sm_75 m.cu graph_list.o -o m

# !./m
# Out:
# Risultati dell'addizione nel kernel CUDA:
# c_host[0] = 11
# c_host[1] = 22
# c_host[2] = 33
# c_host[3] = 44
# c_host[4] = 55
# Node: 10
